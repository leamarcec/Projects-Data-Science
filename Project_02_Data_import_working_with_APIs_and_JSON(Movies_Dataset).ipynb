# %% [markdown]
# ### 1. Importing data from JSON files

# %%
import pandas as pd
import json

# %%
# open and load json file; saving to variable data
with open("blockbusters.json") as f:
    data = json.load(f)

# %%
data
# Out:
# [{'title': 'Avengers: Endgame',
#   'id': 299534,
#   'revenue': 2797800564,
#   'genres': [{'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 28, 'name': 'Action'}],
#   'belongs_to_collection': {'id': 86311,
#    'name': 'The Avengers Collection',
#    'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#    'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#   'runtime': 181},
#  {'title': 'Avatar',
#   'id': 19995,
#   'revenue': 2787965087,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 14, 'name': 'Fantasy'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'belongs_to_collection': {'id': 87096,
#    'name': 'Avatar Collection',
#    'poster_path': '/nslJVsO58Etqkk17oXMuVK4gNOF.jpg',
#    'backdrop_path': '/8nCr9W7sKus2q9PLbYsnT7iCkuT.jpg'},
#   'runtime': 162},
#  {'title': 'Star Wars: The Force Awakens',
#   'id': 140607,
#   'revenue': 2068223624,
# ...

# %%
type(data)
# Out:
# list

# %%
# number of elements
len(data)
# Out:
# 18

# %%
data[0]
# Out:
# {'title': 'Avengers: Endgame',
#  'id': 299534,
#  'revenue': 2797800564,
#  'genres': [{'id': 12, 'name': 'Adventure'},
#   {'id': 878, 'name': 'Science Fiction'},
#   {'id': 28, 'name': 'Action'}],
#  'belongs_to_collection': {'id': 86311,
#   'name': 'The Avengers Collection',
#   'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#   'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#  'runtime': 181}

# %%
# converting dictionary to pandas DataFrame and saving to variable df
df = pd.DataFrame(data)
df
# Out:
#                                            title      id     revenue  \
# 0                              Avengers: Endgame  299534  2797800564
# 1                                         Avatar   19995  2787965087
# 2                   Star Wars: The Force Awakens  140607  2068223624
# 3                         Avengers: Infinity War  299536  2046239637
# 4                                        Titanic     597  1845034188
# 5                                 Jurassic World  135397  1671713208
# 6                                  The Lion King  420818  1656943394
# 7                                   The Avengers   24428  1519557910
# 8                                      Furious 7  168259  1506249360
# 9                        Avengers: Age of Ultron   99861  1405403694
# 10                                 Black Panther  284054  1346739107
# 11  Harry Potter and the Deathly Hallows: Part 2   12445  1341511219
# 12                      Star Wars: The Last Jedi  181808  1332539889
# ...

# %%
df = pd.read_json("blockbusters.json")
df
# Out:
#                                            title      id     revenue  \
# 0                              Avengers: Endgame  299534  2797800564
# 1                                         Avatar   19995  2787965087
# 2                   Star Wars: The Force Awakens  140607  2068223624
# 3                         Avengers: Infinity War  299536  2046239637
# 4                                        Titanic     597  1845034188
# 5                                 Jurassic World  135397  1671713208
# 6                                  The Lion King  420818  1656943394
# 7                                   The Avengers   24428  1519557910
# 8                                      Furious 7  168259  1506249360
# 9                        Avengers: Age of Ultron   99861  1405403694
# 10                                 Black Panther  284054  1346739107
# 11  Harry Potter and the Deathly Hallows: Part 2   12445  1341511219
# 12                      Star Wars: The Last Jedi  181808  1332539889
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  18 non-null     object
#  1   id                     18 non-null     int64
#  2   revenue                18 non-null     int64
#  3   genres                 18 non-null     object
#  4   belongs_to_collection  15 non-null     object
#  5   runtime                18 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 996.0+ bytes

# %%
df.genres[0]
# Out:
# [{'id': 12, 'name': 'Adventure'},
#  {'id': 878, 'name': 'Science Fiction'},
#  {'id': 28, 'name': 'Action'}]

# %%
df.belongs_to_collection[0]
# Out:
# {'id': 86311,
#  'name': 'The Avengers Collection',
#  'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#  'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'}

# %%
pd.json_normalize(data = data, sep = "_")
# Out:
#                                            title      id     revenue  \
# 0                              Avengers: Endgame  299534  2797800564
# 1                                         Avatar   19995  2787965087
# 2                   Star Wars: The Force Awakens  140607  2068223624
# 3                         Avengers: Infinity War  299536  2046239637
# 4                                        Titanic     597  1845034188
# 5                                 Jurassic World  135397  1671713208
# 6                                  The Lion King  420818  1656943394
# 7                                   The Avengers   24428  1519557910
# 8                                      Furious 7  168259  1506249360
# 9                        Avengers: Age of Ultron   99861  1405403694
# 10                                 Black Panther  284054  1346739107
# 11  Harry Potter and the Deathly Hallows: Part 2   12445  1341511219
# 12                      Star Wars: The Last Jedi  181808  1332539889
# ...

# %%
pd.json_normalize(data = data, sep = "_").genres[0]
# Out:
# [{'id': 12, 'name': 'Adventure'},
#  {'id': 878, 'name': 'Science Fiction'},
#  {'id': 28, 'name': 'Action'}]

# %%
pd.json_normalize(data = data, record_path = "genres", meta = ["title", "id"], record_prefix = "genre")
# we can see Avatar has 4 genres
# Out:
#     genreid        genrename                                         title  \
# 0        12        Adventure                             Avengers: Endgame
# 1       878  Science Fiction                             Avengers: Endgame
# 2        28           Action                             Avengers: Endgame
# 3        28           Action                                        Avatar
# 4        12        Adventure                                        Avatar
# 5        14          Fantasy                                        Avatar
# 6       878  Science Fiction                                        Avatar
# 7        28           Action                  Star Wars: The Force Awakens
# 8        12        Adventure                  Star Wars: The Force Awakens
# 9       878  Science Fiction                  Star Wars: The Force Awakens
# 10       14          Fantasy                  Star Wars: The Force Awakens
# ...

# %% [markdown]
# ### 2. Importing data from JSON files (part 2)

# %%
# open and load json file; saving to variable data
with open("blockbusters2.json") as f1:
    data1 = json.load(f1)

# %%
data1
# Out:
# {'title': {'0': 'Avengers: Endgame',
#   '1': 'Avatar',
#   '2': 'Star Wars: The Force Awakens',
#   '3': 'Avengers: Infinity War',
#   '4': 'Titanic',
#   '5': 'Jurassic World',
#   '6': 'The Lion King',
#   '7': 'The Avengers',
#   '8': 'Furious 7',
#   '9': 'Avengers: Age of Ultron',
#   '10': 'Black Panther',
#   '11': 'Harry Potter and the Deathly Hallows: Part 2',
#   '12': 'Star Wars: The Last Jedi',
#   '13': 'Frozen II',
#   '14': 'Jurassic World: Fallen Kingdom',
#   '15': 'Frozen',
#   '16': 'Beauty and the Beast',
#   '17': 'Incredibles 2'},
#  'id': {'0': 299534,
#   '1': 19995,
#   '2': 140607,
#   '3': 299536,
#   '4': 597,
#   '5': 135397,
#   '6': 420818,
#   '7': 24428,
#   '8': 168259,
#   '9': 99861,
#   '10': 284054,
#   '11': 12445,
#   '12': 181808,
#   '13': 330457,
#   '14': 351286,
#   '15': 109445,
#   '16': 321612,
#   '17': 260513},
#  'revenue': {'0': 2797800564,
#   '1': 2787965087,
#   '2': 2068223624,
#   '3': 2046239637,
#   '4': 1845034188,
# ...

# %%
type(data1)
# Out:
# dict

# %%
len(data1)
# Out:
# 6

# %%
#data1[0]

# %%
df1 = pd.DataFrame(data1)
df1
# Out:
#                                            title      id     revenue  \
# 0                              Avengers: Endgame  299534  2797800564
# 1                                         Avatar   19995  2787965087
# 2                   Star Wars: The Force Awakens  140607  2068223624
# 3                         Avengers: Infinity War  299536  2046239637
# 4                                        Titanic     597  1845034188
# 5                                 Jurassic World  135397  1671713208
# 6                                  The Lion King  420818  1656943394
# 7                                   The Avengers   24428  1519557910
# 8                                      Furious 7  168259  1506249360
# 9                        Avengers: Age of Ultron   99861  1405403694
# 10                                 Black Panther  284054  1346739107
# 11  Harry Potter and the Deathly Hallows: Part 2   12445  1341511219
# 12                      Star Wars: The Last Jedi  181808  1332539889
# ...

# %%
df1 = pd.read_json("blockbusters2.json")
df1
# Out:
#                                            title      id     revenue  \
# 0                              Avengers: Endgame  299534  2797800564
# 1                                         Avatar   19995  2787965087
# 2                   Star Wars: The Force Awakens  140607  2068223624
# 3                         Avengers: Infinity War  299536  2046239637
# 4                                        Titanic     597  1845034188
# 5                                 Jurassic World  135397  1671713208
# 6                                  The Lion King  420818  1656943394
# 7                                   The Avengers   24428  1519557910
# 8                                      Furious 7  168259  1506249360
# 9                        Avengers: Age of Ultron   99861  1405403694
# 10                                 Black Panther  284054  1346739107
# 11  Harry Potter and the Deathly Hallows: Part 2   12445  1341511219
# 12                      Star Wars: The Last Jedi  181808  1332539889
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18 entries, 0 to 17
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  18 non-null     object
#  1   id                     18 non-null     int64
#  2   revenue                18 non-null     int64
#  3   genres                 18 non-null     object
#  4   belongs_to_collection  15 non-null     object
#  5   runtime                18 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 1008.0+ bytes

# %%
df1.genres[0]
# Out:
# [{'id': 12, 'name': 'Adventure'},
#  {'id': 878, 'name': 'Science Fiction'},
#  {'id': 28, 'name': 'Action'}]

# %%
df1.belongs_to_collection[0]
# Out:
# {'id': 86311,
#  'name': 'The Avengers Collection',
#  'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#  'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'}

# %%
pd.json_normalize(data = data, sep = "_")
# Out:
#                                            title      id     revenue  \
# 0                              Avengers: Endgame  299534  2797800564
# 1                                         Avatar   19995  2787965087
# 2                   Star Wars: The Force Awakens  140607  2068223624
# 3                         Avengers: Infinity War  299536  2046239637
# 4                                        Titanic     597  1845034188
# 5                                 Jurassic World  135397  1671713208
# 6                                  The Lion King  420818  1656943394
# 7                                   The Avengers   24428  1519557910
# 8                                      Furious 7  168259  1506249360
# 9                        Avengers: Age of Ultron   99861  1405403694
# 10                                 Black Panther  284054  1346739107
# 11  Harry Potter and the Deathly Hallows: Part 2   12445  1341511219
# 12                      Star Wars: The Last Jedi  181808  1332539889
# ...

# %%
pd.json_normalize(data = data, sep = "_").genres[0]
# Out:
# [{'id': 12, 'name': 'Adventure'},
#  {'id': 878, 'name': 'Science Fiction'},
#  {'id': 28, 'name': 'Action'}]

# %%
pd.json_normalize(data = data, record_path = "genres", meta = ["title", "id"], record_prefix = "genres")
# Out:
#     genresid       genresname                                         title  \
# 0         12        Adventure                             Avengers: Endgame
# 1        878  Science Fiction                             Avengers: Endgame
# 2         28           Action                             Avengers: Endgame
# 3         28           Action                                        Avatar
# 4         12        Adventure                                        Avatar
# 5         14          Fantasy                                        Avatar
# 6        878  Science Fiction                                        Avatar
# 7         28           Action                  Star Wars: The Force Awakens
# 8         12        Adventure                  Star Wars: The Force Awakens
# 9        878  Science Fiction                  Star Wars: The Force Awakens
# 10        14          Fantasy                  Star Wars: The Force Awakens
# ...

# %%
# open and load json file; saving to variable data
with open("blockbusters3.json") as f3:
    data3 = json.load(f3)

# %%
type(data3)
# Out:
# dict

# %%
len(data3)
# Out:
# 3

# %%
df3 = pd.read_json("blockbusters3.json", orient = "split")
df3
# Out:
#                                            title      id     revenue  \
# 0                              Avengers: Endgame  299534  2797800564
# 1                                         Avatar   19995  2787965087
# 2                   Star Wars: The Force Awakens  140607  2068223624
# 3                         Avengers: Infinity War  299536  2046239637
# 4                                        Titanic     597  1845034188
# 5                                 Jurassic World  135397  1671713208
# 6                                  The Lion King  420818  1656943394
# 7                                   The Avengers   24428  1519557910
# 8                                      Furious 7  168259  1506249360
# 9                        Avengers: Age of Ultron   99861  1405403694
# 10                                 Black Panther  284054  1346739107
# 11  Harry Potter and the Deathly Hallows: Part 2   12445  1341511219
# 12                      Star Wars: The Last Jedi  181808  1332539889
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18 entries, 0 to 17
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  18 non-null     object
#  1   id                     18 non-null     int64
#  2   revenue                18 non-null     int64
#  3   genres                 18 non-null     object
#  4   belongs_to_collection  15 non-null     object
#  5   runtime                18 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 1008.0+ bytes

# %%
df3.genres[0]
# Out:
# [{'id': 12, 'name': 'Adventure'},
#  {'id': 878, 'name': 'Science Fiction'},
#  {'id': 28, 'name': 'Action'}]

# %%
df3.belongs_to_collection[0]
# Out:
# {'id': 86311,
#  'name': 'The Avengers Collection',
#  'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#  'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'}

# %%
pd.json_normalize(data = data, sep = "_")
# Out:
#                                            title      id     revenue  \
# 0                              Avengers: Endgame  299534  2797800564
# 1                                         Avatar   19995  2787965087
# 2                   Star Wars: The Force Awakens  140607  2068223624
# 3                         Avengers: Infinity War  299536  2046239637
# 4                                        Titanic     597  1845034188
# 5                                 Jurassic World  135397  1671713208
# 6                                  The Lion King  420818  1656943394
# 7                                   The Avengers   24428  1519557910
# 8                                      Furious 7  168259  1506249360
# 9                        Avengers: Age of Ultron   99861  1405403694
# 10                                 Black Panther  284054  1346739107
# 11  Harry Potter and the Deathly Hallows: Part 2   12445  1341511219
# 12                      Star Wars: The Last Jedi  181808  1332539889
# ...

# %%
pd.json_normalize(data = data, sep = "_").genres[0]
# Out:
# [{'id': 12, 'name': 'Adventure'},
#  {'id': 878, 'name': 'Science Fiction'},
#  {'id': 28, 'name': 'Action'}]

# %%
pd.json_normalize(data = data, record_path = "genres", meta = ["title", "id"], record_prefix = "genre")
# Out:
#     genreid        genrename                                         title  \
# 0        12        Adventure                             Avengers: Endgame
# 1       878  Science Fiction                             Avengers: Endgame
# 2        28           Action                             Avengers: Endgame
# 3        28           Action                                        Avatar
# 4        12        Adventure                                        Avatar
# 5        14          Fantasy                                        Avatar
# 6       878  Science Fiction                                        Avatar
# 7        28           Action                  Star Wars: The Force Awakens
# 8        12        Adventure                  Star Wars: The Force Awakens
# 9       878  Science Fiction                  Star Wars: The Force Awakens
# 10       14          Fantasy                  Star Wars: The Force Awakens
# ...

# %% [markdown]
# ### 3. Data import from Web - APIs

# %% [markdown]
# ####  API - Application Programming Interfaces - define how an application communicates with other programms.
# #### The most common way to get data from a web application without knowing database details.
# #### User can tipically pull data from web APIs with HTTP requests and get data in JSON, CSV or other file formats.
# #### How does it work exactly?
# #### --> Defined in the API documentation (if provided)

# %%
api_key = "api_key = 6ed18f48ceb8bd460eb391bc876fd9f7"

# %%
import pandas as pd
import requests
pd.options.display.max_columns=30

# %%
movie_id = 140607

# %%
movie_api = "https://api.themoviedb.org/3/movie/550?"
movie_api
# Out:
# 'https://api.themoviedb.org/3/movie/550?'

# %%
url = "https://api.themoviedb.org/3/movie/550?api_key=6ed18f48ceb8bd460eb391bc876fd9f7"
url
# Out:
# 'https://api.themoviedb.org/3/movie/550?api_key=6ed18f48ceb8bd460eb391bc876fd9f7'

# %%
r = requests.get(url)
r
# Out:
# <Response [200]>

# %%
data4 = r.json()

# %%
data4
# Out:
# {'adult': False,
#  'backdrop_path': '/hZkgoQYus5vegHoetLkCJzb17zJ.jpg',
#  'belongs_to_collection': None,
#  'budget': 63000000,
#  'genres': [{'id': 18, 'name': 'Drama'}],
#  'homepage': 'http://www.foxmovies.com/movies/fight-club',
#  'id': 550,
#  'imdb_id': 'tt0137523',
#  'original_language': 'en',
#  'original_title': 'Fight Club',
#  'overview': 'A ticking-time-bomb insomniac and a slippery soap salesman channel primal male aggression into a shocking new form of therapy. Their concept catches on, with underground "fight clubs" forming in every town, until an eccentric gets in the way and ignites an out-of-control spiral toward oblivion.',
#  'popularity': 65.664,
#  'poster_path': '/pB8BM7pdSp6B6Ih7QZ4DrQ3PmJK.jpg',
#  'production_companies': [{'id': 508,
#    'logo_path': '/7cxRWzi4LsVm4Utfpr1hfARNurT.png',
#    'name': 'Regency Enterprises',
#    'origin_country': 'US'},
#   {'id': 711,
#    'logo_path': '/tEiIH5QesdheJmDAqQwvtN60727.png',
#    'name': 'Fox 2000 Pictures',
# ...

# %%
type(data4)
# Out:
# dict

# %%
#pd.DataFrame(data4)

# %%
pd.Series(data4)
# Out:
# adult                                                                False
# backdrop_path                             /hZkgoQYus5vegHoetLkCJzb17zJ.jpg
# belongs_to_collection                                                 None
# budget                                                            63000000
# genres                                       [{'id': 18, 'name': 'Drama'}]
# homepage                        http://www.foxmovies.com/movies/fight-club
# id                                                                     550
# imdb_id                                                          tt0137523
# original_language                                                       en
# original_title                                                  Fight Club
# overview                 A ticking-time-bomb insomniac and a slippery s...
# popularity                                                          65.664
# ...

# %%
df4 = pd.Series(data4).to_frame().T
df4
# Out:
#    adult                     backdrop_path belongs_to_collection    budget  \
# 0  False  /hZkgoQYus5vegHoetLkCJzb17zJ.jpg                  None  63000000
#
#                           genres                                    homepage  \
# 0  [{'id': 18, 'name': 'Drama'}]  http://www.foxmovies.com/movies/fight-club
#
#     id    imdb_id original_language original_title  \
# 0  550  tt0137523                en     Fight Club
#
#                                             overview popularity  \
# 0  A ticking-time-bomb insomniac and a slippery s...     65.664
#
#                         poster_path  \
# 0  /pB8BM7pdSp6B6Ih7QZ4DrQ3PmJK.jpg
#
#                                 production_companies  \
# 0  [{'id': 508, 'logo_path': '/7cxRWzi4LsVm4Utfpr...
#
#                                 production_countries release_date    revenue  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1999-10-15  100853753
#
# ...

# %%
pd.json_normalize(data = data, sep = "_")
# Out:
#                                            title      id     revenue  \
# 0                              Avengers: Endgame  299534  2797800564
# 1                                         Avatar   19995  2787965087
# 2                   Star Wars: The Force Awakens  140607  2068223624
# 3                         Avengers: Infinity War  299536  2046239637
# 4                                        Titanic     597  1845034188
# 5                                 Jurassic World  135397  1671713208
# 6                                  The Lion King  420818  1656943394
# 7                                   The Avengers   24428  1519557910
# 8                                      Furious 7  168259  1506249360
# 9                        Avengers: Age of Ultron   99861  1405403694
# 10                                 Black Panther  284054  1346739107
# 11  Harry Potter and the Deathly Hallows: Part 2   12445  1341511219
# 12                      Star Wars: The Last Jedi  181808  1332539889
# ...

# %%
pd.json_normalize(data = data, record_path = "genres", meta = "title")
# Out:
#        id             name                                         title
# 0      12        Adventure                             Avengers: Endgame
# 1     878  Science Fiction                             Avengers: Endgame
# 2      28           Action                             Avengers: Endgame
# 3      28           Action                                        Avatar
# 4      12        Adventure                                        Avatar
# 5      14          Fantasy                                        Avatar
# 6     878  Science Fiction                                        Avatar
# 7      28           Action                  Star Wars: The Force Awakens
# 8      12        Adventure                  Star Wars: The Force Awakens
# 9     878  Science Fiction                  Star Wars: The Force Awakens
# 10     14          Fantasy                  Star Wars: The Force Awakens
# 11     12        Adventure                        Avengers: Infinity War
# ...

# %%
# pd.json_normalize(data = data, record_path = "production_companies", meta = "title")

# %% [markdown]
# ### 4. Working with APIs and JSON (part 2)

# %%
discover_api = "https://api.themoviedb.org/3/movie/550?"

# %%
query = "&primary_release_date.gte=2020-01-01&primary_release_date.lte=2020-02-29&page==2"

# %%
url = "https://api.themoviedb.org/3/movie/550?api_key = 6ed18f48ceb8bd460eb391bc876fd9f7&primary_release_date.gte=2020-01-01&primary_release_date.lte=2020-02-29&page==2"

# %%
url
# Out:
# 'https://api.themoviedb.org/3/movie/550?api_key = 6ed18f48ceb8bd460eb391bc876fd9f7&primary_release_date.gte=2020-01-01&primary_release_date.lte=2020-02-29&page==2'

# %%
data5 = requests.get(url).json()

# %%
data5
# Out:
# {'status_code': 7,
#  'status_message': 'Invalid API key: You must be granted a valid key.',
#  'success': False}

# %% [markdown]
# ### 5. Importing and saving the movies dataset (best practice)

# %%
import json

# %%
movie_id = [0, 299534, 19995, 140607, 299536, 597, 135397, 420818, 24428, 168259,
           99861, 284054, 12445, 181808, 330457, 351286, 109445, 321612, 260513]

# %%
basic_url = "https://api.themoviedb.org/3/movie/{}?{}"

# %%
json_list = []
for movie in movie_id:
    url = basic_url.format(movie, api_key)
    r = requests.get(url)
    if r.status_code != 200:
        continue
    else:
        data = r.json()
        json_list.append(data4)
        df = pd.DataFrame(json_list)

# %%
requests.get(basic_url.format(0, api_key)).status_code
# Out:
# 401

# %%
df
# Out:
#                                            title      id     revenue  \
# 0                              Avengers: Endgame  299534  2797800564
# 1                                         Avatar   19995  2787965087
# 2                   Star Wars: The Force Awakens  140607  2068223624
# 3                         Avengers: Infinity War  299536  2046239637
# 4                                        Titanic     597  1845034188
# 5                                 Jurassic World  135397  1671713208
# 6                                  The Lion King  420818  1656943394
# 7                                   The Avengers   24428  1519557910
# 8                                      Furious 7  168259  1506249360
# 9                        Avengers: Age of Ultron   99861  1405403694
# 10                                 Black Panther  284054  1346739107
# 11  Harry Potter and the Deathly Hallows: Part 2   12445  1341511219
# 12                      Star Wars: The Last Jedi  181808  1332539889
# ...

# %% [markdown]
# ### 6. Importing and saving the movies dataset (Real world scenario)

# %%
df.to_csv("movies.csv", index = False)

# %%
df = pd.read_csv("movies.csv")

# %%
df
# Out:
#                                            title      id     revenue  \
# 0                              Avengers: Endgame  299534  2797800564
# 1                                         Avatar   19995  2787965087
# 2                   Star Wars: The Force Awakens  140607  2068223624
# 3                         Avengers: Infinity War  299536  2046239637
# 4                                        Titanic     597  1845034188
# 5                                 Jurassic World  135397  1671713208
# 6                                  The Lion King  420818  1656943394
# 7                                   The Avengers   24428  1519557910
# 8                                      Furious 7  168259  1506249360
# 9                        Avengers: Age of Ultron   99861  1405403694
# 10                                 Black Panther  284054  1346739107
# 11  Harry Potter and the Deathly Hallows: Part 2   12445  1341511219
# 12                      Star Wars: The Last Jedi  181808  1332539889
# ...

# %%
df.genres[0]
# Out:
# "[{'id': 12, 'name': 'Adventure'}, {'id': 878, 'name': 'Science Fiction'}, {'id': 28, 'name': 'Action'}]"
